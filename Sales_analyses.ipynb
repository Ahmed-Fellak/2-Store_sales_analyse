# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("Sales/Sales_January_2019.csv")
df1["month"]='jan'
df2=pd.read_csv("Sales/Sales_February_2019.csv")
df2["month"]='feb'
df3=pd.read_csv("Sales/Sales_March_2019.csv")
df3["month"]='mar'
df4=pd.read_csv("Sales/Sales_April_2019.csv")
df4["month"]='apr'
df5=pd.read_csv("Sales/Sales_May_2019.csv")
df5["month"]='may'
df6=pd.read_csv("Sales/Sales_June_2019.csv")
df6["month"]='june'
df7=pd.read_csv("Sales/Sales_July_2019.csv")
df7["month"]='july'
df8=pd.read_csv("Sales/Sales_August_2019.csv")
df8["month"]='aug'
df9=pd.read_csv("Sales/Sales_September_2019.csv")
df9["month"]='sep'
df10=pd.read_csv("Sales/Sales_October_2019.csv")
df10["month"]='oct'
df11=pd.read_csv("Sales/Sales_November_2019.csv")
df11["month"]='nov'
df12=pd.read_csv("Sales/Sales_December_2019.csv")
df12["month"]='dec'

# %%
list=[df1,df2,df3,df4,df5,df6,df7,df7,df8,df9,df10,df11,df12]

# %%
for i in list:
    print(i.shape)
# Out:
# (9723, 7)
# (12036, 7)
# (15226, 7)
# (18383, 7)
# (16635, 7)
# (13622, 7)
# (14371, 7)
# (14371, 7)
# (12011, 7)
# (11686, 7)
# (20379, 7)
# (17661, 7)
# (25117, 7)

# %%
fram=pd.concat(list,ignore_index=True)
fram
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 201216   319666    Lightning Charging Cable                1      14.95
# 201217   319667       AA Batteries (4-pack)                2       3.84
# 201218   319668             Vareebadd Phone                1        400
# 201219   319669            Wired Headphones                1      11.99
# 201220   319670  Bose SoundSport Headphones                1      99.99
#
#             Order Date                        Purchase Address month
# 0       01/22/19 21:25         944 Walnut St, Boston, MA 02215   jan
# 1       01/28/19 14:15        185 Maple St, Portland, OR 97035   jan
# 2       01/17/19 13:33   538 Adams St, San Francisco, CA 94016   jan
# 3       01/05/19 20:33      738 10th St, Los Angeles, CA 90001   jan
# 4       01/25/19 11:59           387 10th St, Austin, TX 73301   jan
# ...                ...                                     ...   ...
# 201216  12/11/19 20:58  14 Madison St, San Francisco, CA 94016   dec
# 201217  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001   dec
# 201218  12/09/19 06:43        273 Wilson St, Seattle, WA 98101   dec
# 201219  12/03/19 10:39          778 River St, Dallas, TX 75001   dec
# 201220  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001   dec
#
# [201221 rows x 7 columns]

# %%
fram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201221 entries, 0 to 201220
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          200631 non-null  object
#  1   Product           200631 non-null  object
#  2   Quantity Ordered  200631 non-null  object
#  3   Price Each        200631 non-null  object
#  4   Order Date        200631 non-null  object
#  5   Purchase Address  200631 non-null  object
#  6   month             201221 non-null  object
# dtypes: object(7)
# memory usage: 10.7+ MB

# %%
fram.isnull().sum()
# Out:
# Order ID            590
# Product             590
# Quantity Ordered    590
# Price Each          590
# Order Date          590
# Purchase Address    590
# month                 0
# dtype: int64

# %%
fram.duplicated().sum()
# Out:
# 15511

# %%
fram.nunique()
# Out:
# Order ID            178438
# Product                 20
# Quantity Ordered        10
# Price Each              24
# Order Date          142396
# Purchase Address    140788
# month                   12
# dtype: int64

# %%
fram['Product'].unique()
# Out:
# array(['iPhone', 'Lightning Charging Cable', 'Wired Headphones',
#        '27in FHD Monitor', 'AAA Batteries (4-pack)',
#        '27in 4K Gaming Monitor', 'USB-C Charging Cable',
#        'Bose SoundSport Headphones', 'Apple Airpods Headphones',
#        'Macbook Pro Laptop', 'Flatscreen TV', 'Vareebadd Phone',
#        'AA Batteries (4-pack)', 'Google Phone', '20in Monitor',
#        '34in Ultrawide Monitor', 'ThinkPad Laptop', 'LG Dryer',
#        'LG Washing Machine', nan, 'Product'], dtype=object)

# %%
fram.columns=[col.lower() for col in fram]
fram.columns
# Out:
# Index(['order id', 'product', 'quantity ordered', 'price each', 'order date',
#        'purchase address', 'month'],
#       dtype='object')

# %%
fram.rename(columns={
    'order id':'order_id',
    'quantity ordered':'quantity_ordered',
    'price each':'price_each',
    'order date':'order_date',
    'purchase address':'purchase_address'
},inplace=True)

# %%
fram
# Out:
#        order_id                     product quantity_ordered price_each  \
# 0        141234                      iPhone                1        700
# 1        141235    Lightning Charging Cable                1      14.95
# 2        141236            Wired Headphones                2      11.99
# 3        141237            27in FHD Monitor                1     149.99
# 4        141238            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 201216   319666    Lightning Charging Cable                1      14.95
# 201217   319667       AA Batteries (4-pack)                2       3.84
# 201218   319668             Vareebadd Phone                1        400
# 201219   319669            Wired Headphones                1      11.99
# 201220   319670  Bose SoundSport Headphones                1      99.99
#
#             order_date                        purchase_address month
# 0       01/22/19 21:25         944 Walnut St, Boston, MA 02215   jan
# 1       01/28/19 14:15        185 Maple St, Portland, OR 97035   jan
# 2       01/17/19 13:33   538 Adams St, San Francisco, CA 94016   jan
# 3       01/05/19 20:33      738 10th St, Los Angeles, CA 90001   jan
# 4       01/25/19 11:59           387 10th St, Austin, TX 73301   jan
# ...                ...                                     ...   ...
# 201216  12/11/19 20:58  14 Madison St, San Francisco, CA 94016   dec
# 201217  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001   dec
# 201218  12/09/19 06:43        273 Wilson St, Seattle, WA 98101   dec
# 201219  12/03/19 10:39          778 River St, Dallas, TX 75001   dec
# 201220  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001   dec
#
# [201221 rows x 7 columns]

# %%
(fram.isnull().sum().sum())/len(fram)*100
# Out:
# 1.759259719412984

# %%
fram=fram.dropna()
fram.isnull().sum()
# Out:
# order_id            0
# product             0
# quantity_ordered    0
# price_each          0
# order_date          0
# purchase_address    0
# month               0
# dtype: int64

# %%
fram['quantity_ordered'].unique()
# Out:
# array(['1', '2', '3', '5', '4', '7', 'Quantity Ordered', '6', '9', '8'],
#       dtype=object)

# %%
fram['price_each'].unique()
# Out:
# array(['700', '14.95', '11.99', '149.99', '2.99', '389.99', '11.95',
#        '99.99', '150', '1700', '300', '400', '3.84', '600', '109.99',
#        '379.99', '999.99', '600.0', 'Price Each', '700.0', '150.0',
#        '300.0', '1700.0', '400.0'], dtype=object)

# %%
df=fram[fram['quantity_ordered']!='Quantity Ordered']

# %%
df=fram[fram['price_each']!='Price Each']

# %%
df['price_each'].unique()
# Out:
# array(['700', '14.95', '11.99', '149.99', '2.99', '389.99', '11.95',
#        '99.99', '150', '1700', '300', '400', '3.84', '600', '109.99',
#        '379.99', '999.99', '600.0', '700.0', '150.0', '300.0', '1700.0',
#        '400.0'], dtype=object)

# %%
df['quantity_ordered'].unique()
# Out:
# array(['1', '2', '3', '5', '4', '7', '6', '9', '8'], dtype=object)

# %%
df=df.astype({'quantity_ordered':int,'price_each':float})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200241 entries, 0 to 201220
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          200241 non-null  object
#  1   product           200241 non-null  object
#  2   quantity_ordered  200241 non-null  int32
#  3   price_each        200241 non-null  float64
#  4   order_date        200241 non-null  object
#  5   purchase_address  200241 non-null  object
#  6   month             200241 non-null  object
# dtypes: float64(1), int32(1), object(5)
# memory usage: 11.5+ MB

# %%
df['sales']=df['quantity_ordered']*df['price_each']
df
# Out:
#        order_id                     product  quantity_ordered  price_each  \
# 0        141234                      iPhone                 1      700.00
# 1        141235    Lightning Charging Cable                 1       14.95
# 2        141236            Wired Headphones                 2       11.99
# 3        141237            27in FHD Monitor                 1      149.99
# 4        141238            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 201216   319666    Lightning Charging Cable                 1       14.95
# 201217   319667       AA Batteries (4-pack)                 2        3.84
# 201218   319668             Vareebadd Phone                 1      400.00
# 201219   319669            Wired Headphones                 1       11.99
# 201220   319670  Bose SoundSport Headphones                 1       99.99
#
#             order_date                        purchase_address month   sales
# 0       01/22/19 21:25         944 Walnut St, Boston, MA 02215   jan  700.00
# 1       01/28/19 14:15        185 Maple St, Portland, OR 97035   jan   14.95
# 2       01/17/19 13:33   538 Adams St, San Francisco, CA 94016   jan   23.98
# 3       01/05/19 20:33      738 10th St, Los Angeles, CA 90001   jan  149.99
# 4       01/25/19 11:59           387 10th St, Austin, TX 73301   jan   11.99
# ...                ...                                     ...   ...     ...
# 201216  12/11/19 20:58  14 Madison St, San Francisco, CA 94016   dec   14.95
# 201217  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001   dec    7.68
# 201218  12/09/19 06:43        273 Wilson St, Seattle, WA 98101   dec  400.00
# 201219  12/03/19 10:39          778 River St, Dallas, TX 75001   dec   11.99
# 201220  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001   dec   99.99
#
# [200241 rows x 8 columns]

# %%
month_sales=df.groupby('month')['sales'].agg(sales_sum='sum').sort_values(by='sales_sum',ascending=False).reset_index()
month_sales
# Out:
#    month   sales_sum
# 0   july  5293799.38
# 1    dec  4619297.12
# 2    oct  3736884.05
# 3    apr  3396059.11
# 4    nov  3198909.23
# 5    may  3144584.80
# 6    mar  2809063.30
# 7   june  2578293.30
# 8    aug  2244412.31
# 9    feb  2203481.24
# 10   sep  2098816.70
# 11   jan  1815335.12

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax=sns.barplot(x='sales_sum',y='month',data=month_sales)
plt.title('month wise sales')
ax.bar_label(ax.containers[0])
plt.show()

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")
    
def get_stat(address):
    return address.split(",")[2].split(" ")[1]

df['city']=df['purchase_address'].apply(lambda x: get_city(x)+' ( '+ get_stat(x)+')')
df.head()
# Out:
#   order_id                   product  quantity_ordered  price_each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        order_date                       purchase_address month   sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215   jan  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   jan   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   jan   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001   jan  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301   jan   11.99
#
#                   city
# 0         Boston ( MA)
# 1       Portland ( OR)
# 2  San Francisco ( CA)
# 3    Los Angeles ( CA)
# 4         Austin ( TX)

# %%
city_sales=df.groupby('city')['sales'].agg(city_sales='sum').sort_values(by='city_sales',ascending=False).reset_index()
city_sales
# Out:
#                   city  city_sales
# 0  San Francisco ( CA)  8905189.69
# 1    Los Angeles ( CA)  5847422.32
# 2  New York City ( NY)  5019941.22
# 3         Boston ( MA)  3953177.17
# 4        Atlanta ( GA)  3007265.05
# 5         Dallas ( TX)  2978285.63
# 6        Seattle ( WA)  2960269.40
# 7       Portland ( OR)  2014722.99
# 8         Austin ( TX)  1969882.78
# 9       Portland ( ME)   482779.41

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax=sns.barplot(x='city_sales',y='city',data=city_sales)
plt.title('city wise sales')
ax.bar_label(ax.containers[0])
plt.show()

# %%
product_sales=df.groupby('product')['quantity_ordered'].agg(quantity_ordered='sum').sort_values(by='quantity_ordered',ascending=False).reset_index()
product_sales
# Out:
#                        product  quantity_ordered
# 0       AAA Batteries (4-pack)             33383
# 1        AA Batteries (4-pack)             29707
# 2         USB-C Charging Cable             25822
# 3     Lightning Charging Cable             25029
# 4             Wired Headphones             22120
# 5     Apple Airpods Headphones             16882
# 6   Bose SoundSport Headphones             14517
# 7             27in FHD Monitor              8155
# 8                       iPhone              7352
# 9       27in 4K Gaming Monitor              6727
# 10      34in Ultrawide Monitor              6661
# 11                Google Phone              5943
# 12               Flatscreen TV              5218
# 13          Macbook Pro Laptop              5096
# 14                20in Monitor              4456
# 15             ThinkPad Laptop              4448
# 16             Vareebadd Phone              2213
# 17          LG Washing Machine               718
# 18                    LG Dryer               701

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax=sns.barplot(x='quantity_ordered',y='product',data=product_sales)
plt.title('Product wise sales')
ax.bar_label(ax.containers[0])
plt.show()

# %%
time_sales=df
list_time=[]
for i in time_sales['order_date']:
    list_time.append(i.split(" ")[1])

time_sales['time']=list_time
time_sales.head()
# Out:
#   order_id                   product  quantity_ordered  price_each  \
# 0   141234                    iPhone                 1      700.00
# 1   141235  Lightning Charging Cable                 1       14.95
# 2   141236          Wired Headphones                 2       11.99
# 3   141237          27in FHD Monitor                 1      149.99
# 4   141238          Wired Headphones                 1       11.99
#
#        order_date                       purchase_address month   sales  \
# 0  01/22/19 21:25        944 Walnut St, Boston, MA 02215   jan  700.00
# 1  01/28/19 14:15       185 Maple St, Portland, OR 97035   jan   14.95
# 2  01/17/19 13:33  538 Adams St, San Francisco, CA 94016   jan   23.98
# 3  01/05/19 20:33     738 10th St, Los Angeles, CA 90001   jan  149.99
# 4  01/25/19 11:59          387 10th St, Austin, TX 73301   jan   11.99
#
#                   city   time
# 0         Boston ( MA)  21:25
# 1       Portland ( OR)  14:15
# 2  San Francisco ( CA)  13:33
# 3    Los Angeles ( CA)  20:33
# 4         Austin ( TX)  11:59

# %%
time_sales=df.groupby('time')['sales'].agg(time_sales='sum').sort_values(by='time_sales',ascending=False).reset_index()
time_sales
# Out:
#        time  time_sales
# 0     12:21    60203.09
# 1     19:16    60009.21
# 2     19:01    58765.20
# 3     19:20    58356.51
# 4     19:47    57383.45
# ...     ...         ...
# 1435  03:57      442.57
# 1436  04:05      427.71
# 1437  02:50      389.67
# 1438  04:09      285.46
# 1439  03:59      177.29
#
# [1440 rows x 2 columns]

# %%
fig,ax=plt.subplots(figsize=(9,6))
ax=sns.barplot(x='time_sales',y='time',data=time_sales.head())
plt.title('time wise sales')
ax.bar_label(ax.containers[0])
plt.show()
